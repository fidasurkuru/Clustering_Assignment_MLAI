# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv("USArrests.csv")

# %%
df
# Out:
#         Unnamed: 0  Murder  Assault  UrbanPop  Rape
# 0          Alabama    13.2      236        58  21.2
# 1           Alaska    10.0      263        48  44.5
# 2          Arizona     8.1      294        80  31.0
# 3         Arkansas     8.8      190        50  19.5
# 4       California     9.0      276        91  40.6
# 5         Colorado     7.9      204        78  38.7
# 6      Connecticut     3.3      110        77  11.1
# 7         Delaware     5.9      238        72  15.8
# 8          Florida    15.4      335        80  31.9
# 9          Georgia    17.4      211        60  25.8
# 10          Hawaii     5.3       46        83  20.2
# 11           Idaho     2.6      120        54  14.2
# 12        Illinois    10.4      249        83  24.0
# 13         Indiana     7.2      113        65  21.0
# 14            Iowa     2.2       56        57  11.3
# 15          Kansas     6.0      115        66  18.0
# 16        Kentucky     9.7      109        52  16.3
# 17       Louisiana    15.4      249        66  22.2
# 18           Maine     2.1       83        51   7.8
# 19        Maryland    11.3      300        67  27.8
# 20   Massachusetts     4.4      149        85  16.3
# 21        Michigan    12.1      255        74  35.1
# 22       Minnesota     2.7       72        66  14.9
# 23     Mississippi    16.1      259        44  17.1
# 24        Missouri     9.0      178        70  28.2
# 25         Montana     6.0      109        53  16.4
# 26        Nebraska     4.3      102        62  16.5
# 27          Nevada    12.2      252        81  46.0
# 28   New Hampshire     2.1       57        56   9.5
# 29      New Jersey     7.4      159        89  18.8
# 30      New Mexico    11.4      285        70  32.1
# 31        New York    11.1      254        86  26.1
# 32  North Carolina    13.0      337        45  16.1
# 33    North Dakota     0.8       45        44   7.3
# 34            Ohio     7.3      120        75  21.4
# 35        Oklahoma     6.6      151        68  20.0
# 36          Oregon     4.9      159        67  29.3
# 37    Pennsylvania     6.3      106        72  14.9
# 38    Rhode Island     3.4      174        87   8.3
# 39  South Carolina    14.4      279        48  22.5
# 40    South Dakota     3.8       86        45  12.8
# 41       Tennessee    13.2      188        59  26.9
# 42           Texas    12.7      201        80  25.5
# 43            Utah     3.2      120        80  22.9
# 44         Vermont     2.2       48        32  11.2
# 45        Virginia     8.5      156        63  20.7
# 46      Washington     4.0      145        73  26.2
# 47   West Virginia     5.7       81        39   9.3
# 48       Wisconsin     2.6       53        66  10.8
# 49         Wyoming     6.8      161        60  15.6

# %%
data = pd.read_csv("USArrests.csv", index_col = 0)

# %%
data
# Out:
#                 Murder  Assault  UrbanPop  Rape
# Alabama           13.2      236        58  21.2
# Alaska            10.0      263        48  44.5
# Arizona            8.1      294        80  31.0
# Arkansas           8.8      190        50  19.5
# California         9.0      276        91  40.6
# Colorado           7.9      204        78  38.7
# Connecticut        3.3      110        77  11.1
# Delaware           5.9      238        72  15.8
# Florida           15.4      335        80  31.9
# Georgia           17.4      211        60  25.8
# Hawaii             5.3       46        83  20.2
# Idaho              2.6      120        54  14.2
# Illinois          10.4      249        83  24.0
# Indiana            7.2      113        65  21.0
# Iowa               2.2       56        57  11.3
# Kansas             6.0      115        66  18.0
# Kentucky           9.7      109        52  16.3
# Louisiana         15.4      249        66  22.2
# Maine              2.1       83        51   7.8
# Maryland          11.3      300        67  27.8
# Massachusetts      4.4      149        85  16.3
# Michigan          12.1      255        74  35.1
# Minnesota          2.7       72        66  14.9
# Mississippi       16.1      259        44  17.1
# Missouri           9.0      178        70  28.2
# Montana            6.0      109        53  16.4
# Nebraska           4.3      102        62  16.5
# Nevada            12.2      252        81  46.0
# New Hampshire      2.1       57        56   9.5
# New Jersey         7.4      159        89  18.8
# New Mexico        11.4      285        70  32.1
# New York          11.1      254        86  26.1
# North Carolina    13.0      337        45  16.1
# North Dakota       0.8       45        44   7.3
# Ohio               7.3      120        75  21.4
# Oklahoma           6.6      151        68  20.0
# Oregon             4.9      159        67  29.3
# Pennsylvania       6.3      106        72  14.9
# Rhode Island       3.4      174        87   8.3
# South Carolina    14.4      279        48  22.5
# South Dakota       3.8       86        45  12.8
# Tennessee         13.2      188        59  26.9
# Texas             12.7      201        80  25.5
# Utah               3.2      120        80  22.9
# Vermont            2.2       48        32  11.2
# Virginia           8.5      156        63  20.7
# Washington         4.0      145        73  26.2
# West Virginia      5.7       81        39   9.3
# Wisconsin          2.6       53        66  10.8
# Wyoming            6.8      161        60  15.6

# %%
data.head(3)
# Out:
#          Murder  Assault  UrbanPop  Rape
# Alabama    13.2      236        58  21.2
# Alaska     10.0      263        48  44.5
# Arizona     8.1      294        80  31.0

# %%
data.tail(3)
# Out:
#                Murder  Assault  UrbanPop  Rape
# West Virginia     5.7       81        39   9.3
# Wisconsin         2.6       53        66  10.8
# Wyoming           6.8      161        60  15.6

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, Alabama to Wyoming
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Murder    50 non-null     float64
#  1   Assault   50 non-null     int64
#  2   UrbanPop  50 non-null     int64
#  3   Rape      50 non-null     float64
# dtypes: float64(2), int64(2)
# memory usage: 2.0+ KB

# %%
data.describe()
# Out:
#          Murder     Assault   UrbanPop       Rape
# count  50.00000   50.000000  50.000000  50.000000
# mean    7.78800  170.760000  65.540000  21.232000
# std     4.35551   83.337661  14.474763   9.366385
# min     0.80000   45.000000  32.000000   7.300000
# 25%     4.07500  109.000000  54.500000  15.075000
# 50%     7.25000  159.000000  66.000000  20.100000
# 75%    11.25000  249.000000  77.750000  26.175000
# max    17.40000  337.000000  91.000000  46.000000

# %%
plt.hist(data["Murder"])
plt.show()

# %%
plt.hist(data["Assault"])
plt.show()

# %%
plt.boxplot(data['Assault'])
plt.show()

# %%
sns.boxplot(data['Assault'])
plt.show()
# Out:
# C:\Users\USER_PC\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(y = data['Assault'])
plt.show()

# %%
sns.scatterplot(x = "Murder", y = "Rape", data = data)
plt.show()

# %%
sns.pairplot(data)
plt.show()

# %%
data.isna().sum()
# Out:
# Murder      0
# Assault     0
# UrbanPop    0
# Rape        0
# dtype: int64

# %%
x = data

# %% [markdown]
# Kmeans

# %%
from sklearn.cluster import KMeans

# %%
kmean_inst = KMeans(n_clusters=6)

# %%
kmean_inst.fit(x)
# Out:
# KMeans(n_clusters=6)

# %%
kmean_inst.inertia_
# Out:
# 18768.000666666667

# %%
kmean_inst.cluster_centers_
# Out:
# array([[ 11.76666667, 257.91666667,  68.41666667,  28.93333333],
#        [  5.59      , 112.4       ,  65.6       ,  17.27      ],
#        [ 11.95      , 316.5       ,  68.        ,  26.7       ],
#        [  5.75      , 156.75      ,  74.        ,  19.4       ],
#        [  2.95      ,  62.7       ,  53.9       ,  11.51      ],
#        [ 11.5       , 195.33333333,  66.16666667,  27.43333333]])

# %%
kmean_inst.labels_
# Out:
# array([0, 0, 2, 5, 0, 5, 1, 0, 2, 5, 4, 1, 0, 1, 4, 1, 1, 0, 4, 2, 3, 0,
#        4, 0, 5, 1, 1, 0, 4, 3, 0, 0, 2, 4, 1, 3, 3, 1, 3, 0, 4, 5, 5, 1,
#        4, 3, 3, 4, 4, 3])

# %%
plt.scatter(data['Murder'], data['Assault'], c = kmean_inst.labels_)
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

# %%
km_labels = kmean_inst.labels_

# %%
data['km_clus_label'] = km_labels

# %%
# data

# %%
sc = StandardScaler()
x = sc.fit_transform(data)

# %%
from scipy.cluster.hierarchy import linkage
from scipy.cluster.hierarchy import dendrogram

# %%
mergings = linkage(x , method = "average")

# %%
plt.figure(figsize=(10,6))
dendrogram(mergings, labels = data.index)
plt.show()

# %% [markdown]
# Agglomerative clustering models

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
# Initialize the model
agg = AgglomerativeClustering(n_clusters=3)

# %%
# Fit the model to the data
agg.fit(data)
# Out:
# AgglomerativeClustering(n_clusters=3)

# %%
# Predict the clusters for each data point
labels = agg.labels_

# %%
# Add the labels to the dataframe
data['Cluster'] = labels

# %%
data
# Out:
#                 Murder  Assault  UrbanPop  Rape  km_clus_label  Cluster
# Alabama           13.2      236        58  21.2              0        1
# Alaska            10.0      263        48  44.5              0        1
# Arizona            8.1      294        80  31.0              2        1
# Arkansas           8.8      190        50  19.5              5        2
# California         9.0      276        91  40.6              0        1
# Colorado           7.9      204        78  38.7              5        2
# Connecticut        3.3      110        77  11.1              1        0
# Delaware           5.9      238        72  15.8              0        1
# Florida           15.4      335        80  31.9              2        1
# Georgia           17.4      211        60  25.8              5        2
# Hawaii             5.3       46        83  20.2              4        0
# Idaho              2.6      120        54  14.2              1        0
# Illinois          10.4      249        83  24.0              0        1
# Indiana            7.2      113        65  21.0              1        0
# Iowa               2.2       56        57  11.3              4        0
# Kansas             6.0      115        66  18.0              1        0
# Kentucky           9.7      109        52  16.3              1        0
# Louisiana         15.4      249        66  22.2              0        1
# Maine              2.1       83        51   7.8              4        0
# Maryland          11.3      300        67  27.8              2        1
# Massachusetts      4.4      149        85  16.3              3        2
# Michigan          12.1      255        74  35.1              0        1
# Minnesota          2.7       72        66  14.9              4        0
# Mississippi       16.1      259        44  17.1              0        1
# Missouri           9.0      178        70  28.2              5        2
# Montana            6.0      109        53  16.4              1        0
# Nebraska           4.3      102        62  16.5              1        0
# Nevada            12.2      252        81  46.0              0        1
# New Hampshire      2.1       57        56   9.5              4        0
# New Jersey         7.4      159        89  18.8              3        2
# New Mexico        11.4      285        70  32.1              0        1
# New York          11.1      254        86  26.1              0        1
# North Carolina    13.0      337        45  16.1              2        1
# North Dakota       0.8       45        44   7.3              4        0
# Ohio               7.3      120        75  21.4              1        0
# Oklahoma           6.6      151        68  20.0              3        2
# Oregon             4.9      159        67  29.3              3        2
# Pennsylvania       6.3      106        72  14.9              1        0
# Rhode Island       3.4      174        87   8.3              3        2
# South Carolina    14.4      279        48  22.5              0        1
# South Dakota       3.8       86        45  12.8              4        0
# Tennessee         13.2      188        59  26.9              5        2
# Texas             12.7      201        80  25.5              5        2
# Utah               3.2      120        80  22.9              1        0
# Vermont            2.2       48        32  11.2              4        0
# Virginia           8.5      156        63  20.7              3        2
# Washington         4.0      145        73  26.2              3        2
# West Virginia      5.7       81        39   9.3              4        0
# Wisconsin          2.6       53        66  10.8              4        0
# Wyoming            6.8      161        60  15.6              3        2

# %%
# the mean values of each feature for each cluster:
print(data.groupby(['Cluster']).mean())
# Out:
#             Murder     Assault   UrbanPop       Rape  km_clus_label
# Cluster
# 0         4.270000   87.550000  59.750000  14.390000       2.500000
# 1        11.812500  272.562500  68.312500  28.375000       0.500000
# 2         8.214286  173.285714  70.642857  22.842857       3.857143
